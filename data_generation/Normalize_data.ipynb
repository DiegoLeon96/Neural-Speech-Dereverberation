# %%
# !pip install soundfile
# !pip install librosa==0.8.0
# !pip install scipy==1.5.2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import librosa
import librosa.display as display
import librosa.feature
import soundfile as sf
import os
import sys
import torch
import cv2
import random
import math
# Out:
# ...
#      |████████████████████████████████| 25.9MB 1.5MB/s
# ...
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ...

# %%
def normalize(spec, eps=1e-6):
  """
  Zero mean and unitary variance normalization
  """
  mean = spec.mean()
  std = spec.std()
  spec_norm = (spec - mean) / (std + eps)
  return spec_norm, (mean, std)

def minmax_scaler(spec):
  """
  min max scaler over spectrogram
  """
  spec_max = np.max(spec)
  spec_min = np.min(spec)

  return (spec- spec_min)/(spec_max - spec_min), (spec_max, spec_min)

def linear_scaler(spec):
  """
  linear scaler over spectrogram
  min value -> -1 and max value -> 1
  """
  spec_max = np.max(spec)
  spec_min = np.min(spec)
  m = 2/(spec_max-spec_min)
  n = (spec_max + spec_min)/(spec_min-spec_max)

  return m*spec + n, (m, n)

def normalize_data(X_path, y_path, checkpoints):
  """
  Use zero mean and unitary variance normalization over spectrograms

  X_path: directory containing tensor with non-normalized reverberant spectrograms
  y_path: directory containing tensor with non-normalized target spectrograms
  checkpoints: list of 2 directories to save normalized reverberant and target
               spectrograms respectively

  """
  
  checkpointX = checkpoints[0]
  checkpointY = checkpoints[1]
  X = torch.load(X_path)
  y = torch.load(y_path)

  for i in range(X.shape[0]):
    print("Processing specgram n°:" + str(i+1))
    spec_rev = X[i, 0, :, :].numpy()
    spec_target = y[i, 0, :, :].numpy()

    spec_rev_norm, _ = normalize(spec_rev)
    spec_target_norm, _ = normalize(spec_target)

    X[i, 0, :, :] = torch.tensor(spec_rev_norm)
    y[i, 0, :, :] = torch.tensor(spec_target_norm)
    
  torch.save(X, checkpointX)
  torch.save(y, checkpointY)

def normalize_linear_data(X_path, y_path, checkpoints):
  """
  Use linear normalization over spectrograms

  X_path: directory containing tensor with non-normalized reverberant spectrograms
  y_path: directory containing tensor with non-normalized target spectrograms
  checkpoints: list of 2 directories to save normalized reverberant and target
               spectrograms respectively

  """

  checkpointX = checkpoints[0]
  checkpointY = checkpoints[1]
  X = torch.load(X_path)
  y = torch.load(y_path)

  for i in range(X.shape[0]):
    print("Processing specgram n°:" + str(i+1))
    spec_rev = X[i, 0, :, :].numpy()
    spec_target = y[i, 0, :, :].numpy()

    spec_rev_norm, _ = normalize(spec_rev)
    spec_target_norm, _ = normalize(spec_target)

    X[i, 0, :, :] = torch.tensor(spec_rev_norm)
    y[i, 0, :, :] = torch.tensor(spec_target_norm)
    
  torch.save(X, checkpointX)
  torch.save(y, checkpointY)

# %%
X_path = '/content/drive/My Drive/data_audio/X_train_1'
y_path = '/content/drive/My Drive/data_audio/y_train_1'
checkpoints = ['/content/drive/My Drive/data_audio/X_train_n1', '/content/drive/My Drive/data_audio/y_train_n1']

normalize_data(X_path, y_path, checkpoints)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Processing specgram n°:1
# Processing specgram n°:2
# Processing specgram n°:3
# Processing specgram n°:4
# Processing specgram n°:5
# Processing specgram n°:6
# Processing specgram n°:7
# Processing specgram n°:8
# Processing specgram n°:9
# Processing specgram n°:10
# Processing specgram n°:11
# Processing specgram n°:12
# Processing specgram n°:13
# Processing specgram n°:14
# Processing specgram n°:15
# Processing specgram n°:16
# Processing specgram n°:17
# Processing specgram n°:18
# Processing specgram n°:19
# Processing specgram n°:20
# Processing specgram n°:21
# Processing specgram n°:22
# Processing specgram n°:23
# Processing specgram n°:24
# Processing specgram n°:25
# Processing specgram n°:26
# Processing specgram n°:27
# Processing specgram n°:28
# Processing specgram n°:29
# Processing specgram n°:30
# Processing specgram n°:31
# Processing specgram n°:32
# Processing specgram n°:33
# ...

# %%
X_path = '/content/drive/My Drive/data_audio/X_train_2'
y_path = '/content/drive/My Drive/data_audio/y_train_2'
checkpoints = ['/content/drive/My Drive/data_audio/X_train_n2', '/content/drive/My Drive/data_audio/y_train_n2']

normalize_data(X_path, y_path, checkpoints)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Processing specgram n°:1
# Processing specgram n°:2
# Processing specgram n°:3
# Processing specgram n°:4
# Processing specgram n°:5
# Processing specgram n°:6
# Processing specgram n°:7
# Processing specgram n°:8
# Processing specgram n°:9
# Processing specgram n°:10
# Processing specgram n°:11
# Processing specgram n°:12
# Processing specgram n°:13
# Processing specgram n°:14
# Processing specgram n°:15
# Processing specgram n°:16
# Processing specgram n°:17
# Processing specgram n°:18
# Processing specgram n°:19
# Processing specgram n°:20
# Processing specgram n°:21
# Processing specgram n°:22
# Processing specgram n°:23
# Processing specgram n°:24
# Processing specgram n°:25
# Processing specgram n°:26
# Processing specgram n°:27
# Processing specgram n°:28
# Processing specgram n°:29
# Processing specgram n°:30
# Processing specgram n°:31
# Processing specgram n°:32
# Processing specgram n°:33
# ...

# %%
X_path = '/content/drive/My Drive/data_audio/X_train_3'
y_path = '/content/drive/My Drive/data_audio/y_train_3'
checkpoints = ['/content/drive/My Drive/data_audio/X_train_n3', '/content/drive/My Drive/data_audio/y_train_n3']

normalize_data(X_path, y_path, checkpoints)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Processing specgram n°:1
# Processing specgram n°:2
# Processing specgram n°:3
# Processing specgram n°:4
# Processing specgram n°:5
# Processing specgram n°:6
# Processing specgram n°:7
# Processing specgram n°:8
# Processing specgram n°:9
# Processing specgram n°:10
# Processing specgram n°:11
# Processing specgram n°:12
# Processing specgram n°:13
# Processing specgram n°:14
# Processing specgram n°:15
# Processing specgram n°:16
# Processing specgram n°:17
# Processing specgram n°:18
# Processing specgram n°:19
# Processing specgram n°:20
# Processing specgram n°:21
# Processing specgram n°:22
# Processing specgram n°:23
# Processing specgram n°:24
# Processing specgram n°:25
# Processing specgram n°:26
# Processing specgram n°:27
# Processing specgram n°:28
# Processing specgram n°:29
# Processing specgram n°:30
# Processing specgram n°:31
# Processing specgram n°:32
# Processing specgram n°:33
# ...

# %%
X_path = '/content/drive/My Drive/data_audio/X_train_4'
y_path = '/content/drive/My Drive/data_audio/y_train_4'
checkpoints = ['/content/drive/My Drive/data_audio/X_train_n4', '/content/drive/My Drive/data_audio/y_train_n4']

normalize_data(X_path, y_path, checkpoints)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Processing specgram n°:1
# Processing specgram n°:2
# Processing specgram n°:3
# Processing specgram n°:4
# Processing specgram n°:5
# Processing specgram n°:6
# Processing specgram n°:7
# Processing specgram n°:8
# Processing specgram n°:9
# Processing specgram n°:10
# Processing specgram n°:11
# Processing specgram n°:12
# Processing specgram n°:13
# Processing specgram n°:14
# Processing specgram n°:15
# Processing specgram n°:16
# Processing specgram n°:17
# Processing specgram n°:18
# Processing specgram n°:19
# Processing specgram n°:20
# Processing specgram n°:21
# Processing specgram n°:22
# Processing specgram n°:23
# Processing specgram n°:24
# Processing specgram n°:25
# Processing specgram n°:26
# Processing specgram n°:27
# Processing specgram n°:28
# Processing specgram n°:29
# Processing specgram n°:30
# Processing specgram n°:31
# Processing specgram n°:32
# Processing specgram n°:33
# ...

# %%
X_path = '/content/drive/My Drive/data_audio/X_train1'
y_path = '/content/drive/My Drive/data_audio/y_train1'
checkpoints = ['/content/drive/My Drive/linear_norm_data/X_train_n1', '/content/drive/My Drive/linear_norm_data/y_train_n1']

normalize_linear_data(X_path, y_path, checkpoints)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Processing specgram n°:1
# Processing specgram n°:2
# Processing specgram n°:3
# Processing specgram n°:4
# Processing specgram n°:5
# Processing specgram n°:6
# Processing specgram n°:7
# Processing specgram n°:8
# Processing specgram n°:9
# Processing specgram n°:10
# Processing specgram n°:11
# Processing specgram n°:12
# Processing specgram n°:13
# Processing specgram n°:14
# Processing specgram n°:15
# Processing specgram n°:16
# Processing specgram n°:17
# Processing specgram n°:18
# Processing specgram n°:19
# Processing specgram n°:20
# Processing specgram n°:21
# Processing specgram n°:22
# Processing specgram n°:23
# Processing specgram n°:24
# Processing specgram n°:25
# Processing specgram n°:26
# Processing specgram n°:27
# Processing specgram n°:28
# Processing specgram n°:29
# Processing specgram n°:30
# Processing specgram n°:31
# Processing specgram n°:32
# Processing specgram n°:33
# ...

# %%
X_path = '/content/drive/My Drive/data_audio/X_train2'
y_path = '/content/drive/My Drive/data_audio/y_train2'
checkpoints = ['/content/drive/My Drive/linear_norm_data/X_train_n2', '/content/drive/My Drive/linear_norm_data/y_train_n2']

normalize_linear_data(X_path, y_path, checkpoints)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Processing specgram n°:1
# Processing specgram n°:2
# Processing specgram n°:3
# Processing specgram n°:4
# Processing specgram n°:5
# Processing specgram n°:6
# Processing specgram n°:7
# Processing specgram n°:8
# Processing specgram n°:9
# Processing specgram n°:10
# Processing specgram n°:11
# Processing specgram n°:12
# Processing specgram n°:13
# Processing specgram n°:14
# Processing specgram n°:15
# Processing specgram n°:16
# Processing specgram n°:17
# Processing specgram n°:18
# Processing specgram n°:19
# Processing specgram n°:20
# Processing specgram n°:21
# Processing specgram n°:22
# Processing specgram n°:23
# Processing specgram n°:24
# Processing specgram n°:25
# Processing specgram n°:26
# Processing specgram n°:27
# Processing specgram n°:28
# Processing specgram n°:29
# Processing specgram n°:30
# Processing specgram n°:31
# Processing specgram n°:32
# Processing specgram n°:33
# ...

# %%
X_path = '/content/drive/My Drive/data_audio/X_train3'
y_path = '/content/drive/My Drive/data_audio/y_train3'
checkpoints = ['/content/drive/My Drive/linear_norm_data/X_train_n3', '/content/drive/My Drive/linear_norm_data/y_train_n3']

normalize_linear_data(X_path, y_path, checkpoints)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Processing specgram n°:1
# Processing specgram n°:2
# Processing specgram n°:3
# Processing specgram n°:4
# Processing specgram n°:5
# Processing specgram n°:6
# Processing specgram n°:7
# Processing specgram n°:8
# Processing specgram n°:9
# Processing specgram n°:10
# Processing specgram n°:11
# Processing specgram n°:12
# Processing specgram n°:13
# Processing specgram n°:14
# Processing specgram n°:15
# Processing specgram n°:16
# Processing specgram n°:17
# Processing specgram n°:18
# Processing specgram n°:19
# Processing specgram n°:20
# Processing specgram n°:21
# Processing specgram n°:22
# Processing specgram n°:23
# Processing specgram n°:24
# Processing specgram n°:25
# Processing specgram n°:26
# Processing specgram n°:27
# Processing specgram n°:28
# Processing specgram n°:29
# Processing specgram n°:30
# Processing specgram n°:31
# Processing specgram n°:32
# Processing specgram n°:33
# ...

# %%
X_path = '/content/drive/My Drive/data_audio/X_train4'
y_path = '/content/drive/My Drive/data_audio/y_train4'
checkpoints = ['/content/drive/My Drive/linear_norm_data/X_train_n4', '/content/drive/My Drive/linear_norm_data/y_train_n4']

normalize_linear_data(X_path, y_path, checkpoints)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Processing specgram n°:1
# Processing specgram n°:2
# Processing specgram n°:3
# Processing specgram n°:4
# Processing specgram n°:5
# Processing specgram n°:6
# Processing specgram n°:7
# Processing specgram n°:8
# Processing specgram n°:9
# Processing specgram n°:10
# Processing specgram n°:11
# Processing specgram n°:12
# Processing specgram n°:13
# Processing specgram n°:14
# Processing specgram n°:15
# Processing specgram n°:16
# Processing specgram n°:17
# Processing specgram n°:18
# Processing specgram n°:19
# Processing specgram n°:20
# Processing specgram n°:21
# Processing specgram n°:22
# Processing specgram n°:23
# Processing specgram n°:24
# Processing specgram n°:25
# Processing specgram n°:26
# Processing specgram n°:27
# Processing specgram n°:28
# Processing specgram n°:29
# Processing specgram n°:30
# Processing specgram n°:31
# Processing specgram n°:32
# Processing specgram n°:33
# ...
